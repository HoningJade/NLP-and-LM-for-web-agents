# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
models = ['R@1', 'R@5', 'R@10', 'R@50']
r_at_1 = [0.34, 0.62, 0.81, 0.98]
r_at_5 = [0.3741,0.6512,0.8133,0.9754]
r_at_10 = [ 0.08276,0.21034,0.28793,0.51552]


# Bar width
bar_width = 0.2

# Set the positions of bars on X-axis
r = np.arange(len(models))

# Create the grouped bar chart
plt.bar(r - 1.5 * bar_width, r_at_1, width=bar_width, label='T5')
plt.bar(r - 0.5 * bar_width, r_at_5, width=bar_width, label='DeBERTa')
plt.bar(r + 0.5 * bar_width, r_at_10, width=bar_width, label='ColBERT')

# Add labels and title
plt.xlabel('k')
plt.ylabel('Recall')
plt.title('Performance Comparison by R@k')
plt.xticks(r, models)

# Add legend
plt.legend(title='Models')

# Show the chart
plt.show()
